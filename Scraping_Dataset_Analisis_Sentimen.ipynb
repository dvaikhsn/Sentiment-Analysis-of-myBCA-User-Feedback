# %% [markdown]
# # **PROYEK ANALISIS SENTIMEN PADA APLIKASI MY BCA**
# ## **PENGAMBILAN DATASET DARI GOOGLE PLAYSTORE**
# ### **Nama : Dava Ikhsan Reyvan**
#
# ### **Email : dvaikhsn@gmail.com**
#
# ### **Dicoding : dvaikhsn**

# %% [markdown]
# ### **Scarping Dataset from Google Playstore**

# %%
# !pip install google-play-scraper pandas

# %% [markdown]
# ### **Import Library yang dibutuhkan**

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Aplikasi yang mau di scarp**

# %%
from google_play_scraper import Sort, reviews_all

scrap_apk = reviews_all(
    'com.bca.mybca.omni.android',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT
)

# %% [markdown]
# ###**Menyimpan hasil scarping**

# %%
import csv

with open('ulasan my-bca.csv', mode='w', newline='', encoding='utf-8') as file:
  writer = csv.writer(file)
  writer.writerow(['Reviews'])
  for review in scrap_apk:
    writer.writerow([review['content']])

# %% [markdown]
# ### **Loading Dataset**

# %%
apk_review_df = pd.DataFrame(scrap_apk)
apk_review_df.to_csv('ulasan my-bca.csv', index=False)

# %%
apk_review_df
# Out:
#                                    reviewId         userName  \
# 0      5adde649-5c35-437d-8e0a-2e56c5857928  Pengguna Google
# 1      1e28c1b6-6ab4-49e3-9979-c6a3db92d185  Pengguna Google
# 2      1e08f007-d87a-42cd-9146-8d76eefa1938  Pengguna Google
# 3      d472fe53-6ea2-4276-b18d-2988a71850fe  Pengguna Google
# 4      4eee238d-e930-4397-bce1-96cb3f658356  Pengguna Google
# ...                                     ...              ...
# 20145  7f13aa7b-3209-4a1e-b4b8-5d0469e1bbf2  Pengguna Google
# 20146  56555fa3-1b32-4bea-bddb-0ccbf5a55590  Pengguna Google
# 20147  ca175c7e-e2d5-41a4-8b16-6c32ad864cf2  Pengguna Google
# 20148  a5963129-da65-4c61-859d-fa8e96ed54e7  Pengguna Google
# 20149  90cb0715-1bb0-4b03-af40-d69a071a82c2  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
apk_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20150 entries, 0 to 20149
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              20150 non-null  object
#  1   userName              20150 non-null  object
#  2   userImage             20150 non-null  object
#  3   content               20150 non-null  object
#  4   score                 20150 non-null  int64
#  5   thumbsUpCount         20150 non-null  int64
#  6   reviewCreatedVersion  15428 non-null  object
#  7   at                    20150 non-null  datetime64[ns]
#  8   replyContent          20150 non-null  object
#  9   repliedAt             20150 non-null  datetime64[ns]
#  10  appVersion            15428 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.7+ MB
